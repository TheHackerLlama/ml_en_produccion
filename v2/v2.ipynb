# %%
# !unzip hot-dog-not-hot-dog.zip

# %%
import tensorflow as tf

print("Hay GPU disponible: "),
print(tf.test.is_gpu_available())
# Out:
# Hay GPU disponible:
# True

# %%
import os

train_path = 'train'
test_path = 'test'

# %%
import numpy as np
from tensorflow.python.keras.preprocessing.image import load_img, img_to_array
from tensorflow.python import keras
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator

img_size = 224
num_classes = 2

data_generator = ImageDataGenerator()

train_generator = data_generator.flow_from_directory(
        train_path,
        target_size=(img_size, img_size),
        batch_size=498,
        class_mode='categorical')

test_generator = data_generator.flow_from_directory(
        test_path,
        target_size=(img_size, img_size),
        batch_size=500,
        class_mode='categorical')
# Out:
# Found 498 images belonging to 2 classes.
# Found 500 images belonging to 2 classes.

# %%
print(len(train_generator))
print(len(train_generator[0]))
print(train_generator[0][0].shape)
# Out:
# 1
# 2
# (498, 224, 224, 3)

# %%
from tensorflow.python import keras
from tensorflow.python.keras import Sequential
from tensorflow.python.keras.layers import Flatten, Dense, Conv2D, Dropout
import itertools


model = Sequential()
model.add(Conv2D(8, kernel_size=(3,3),
            activation='relu',
            input_shape=(img_size, img_size, 3)))
Dropout(.5)
model.add(Conv2D(8, kernel_size=(3,3),
            activation='relu'))
Dropout(.5)

model.add(Conv2D(8, kernel_size=(3,3),
                activation='relu'))
model.add(Conv2D(8, kernel_size=(3,3),
                activation='relu'))
model.add(Conv2D(8, kernel_size=(3,3),
                activation='relu'))
model.add(Conv2D(8, kernel_size=(3,3),
                activation='relu'))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_26 (Conv2D)           (None, 222, 222, 8)       224
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 220, 220, 8)       584
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 218, 218, 8)       584
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 216, 216, 8)       584
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 214, 214, 8)       584
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 212, 212, 8)       584
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 359552)            0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               46022784
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 46,026,186
# Trainable params: 46,026,186
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss=keras.losses.categorical_crossentropy,
             optimizer='adam',
             metrics=['accuracy'])

# %%
input_x = (train_generator[0][0]/255)
input_y = (train_generator[0][1])

# %%
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint('saved_model', monitor='val_acc', verbose=1, 
                             save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
model.fit(input_x,
         input_y,
         batch_size=24,
         epochs=30,
         callbacks=callbacks_list,
         validation_split=0.2)
# Out:
# Train on 398 samples, validate on 100 samples
# Epoch 1/30
# 384/398 [===========================>..] - ETA: 0s - loss: 0.7887 - acc: 0.5260
# Epoch 00001: val_acc improved from -inf to 0.51000, saving model to saved_model
# 398/398 [==============================] - 8s 19ms/step - loss: 0.7853 - acc: 0.5302 - val_loss: 0.6926 - val_acc: 0.5100
# Epoch 2/30
# 384/398 [===========================>..] - ETA: 0s - loss: 0.6806 - acc: 0.5885
# Epoch 00002: val_acc improved from 0.51000 to 0.52000, saving model to saved_model
# 398/398 [==============================] - 6s 14ms/step - loss: 0.6812 - acc: 0.5804 - val_loss: 0.6912 - val_acc: 0.5200
# Epoch 3/30
# 384/398 [===========================>..] - ETA: 0s - loss: 0.6352 - acc: 0.7057
# Epoch 00022: val_acc did not improve from 0.56000
# 398/398 [==============================] - 3s 8ms/step - loss: 2.0609e-05 - acc: 1.0000 - val_loss: 2.5607 - val_acc: 0.5300
# Epoch 23/30
# 384/398 [===========================>..] - ETA: 0s - loss: 1.9249e-05 - acc: 1.0000
# Epoch 00023: val_acc did not improve from 0.56000
# 398/398 [==============================] - 3s 8ms/step - loss: 1.9045e-05 - acc: 1.0000 - val_loss: 2.5856 - val_acc: 0.5300
# Epoch 24/30
# 384/398 [===========================>..] - ETA: 0s - loss: 1.6109e-05 - acc: 1.0000
# Epoch 00024: val_acc did not improve from 0.56000
# 398/398 [==============================] - 3s 8ms/step - loss: 1.7456e-05 - acc: 1.0000 - val_loss: 2.5975 - val_acc: 0.5300
# Epoch 25/30
# 384/398 [===========================>..] - ETA: 0s - loss: 1.6236e-05 - acc: 1.0000
# Epoch 00025: val_acc did not improve from 0.56000
# 398/398 [==============================] - 3s 8ms/step - loss: 1.5972e-05 - acc: 1.0000 - val_loss: 2.6225 - val_acc: 0.5300
# Epoch 26/30
# 384/398 [===========================>..] - ETA: 0s - loss: 1.3060e-05 - acc: 1.0000
# Epoch 00026: val_acc did not improve from 0.56000
# 398/398 [==============================] - 3s 8ms/step - loss: 1.4737e-05 - acc: 1.0000 - val_loss: 2.6410 - val_acc: 0.5300
# Epoch 27/30
# 384/398 [===========================>..] - ETA: 0s - loss: 1.3922e-05 - acc: 1.0000
# Epoch 00027: val_acc did not improve from 0.56000
# 398/398 [==============================] - 3s 8ms/step - loss: 1.3777e-05 - acc: 1.0000 - val_loss: 2.6663 - val_acc: 0.5300
# Epoch 28/30
# 384/398 [===========================>..] - ETA: 0s - loss: 1.3003e-05 - acc: 1.0000
# Epoch 00028: val_acc did not improve from 0.56000
# 398/398 [==============================] - 3s 8ms/step - loss: 1.2683e-05 - acc: 1.0000 - val_loss: 2.6810 - val_acc: 0.5300
# Epoch 29/30
# 384/398 [===========================>..] - ETA: 0s - loss: 1.2240e-05 - acc: 1.0000
# Epoch 00029: val_acc did not improve from 0.56000
# 398/398 [==============================] - 3s 8ms/step - loss: 1.1819e-05 - acc: 1.0000 - val_loss: 2.6936 - val_acc: 0.5300
# Epoch 30/30
# 384/398 [===========================>..] - ETA: 0s - loss: 1.1472e-05 - acc: 1.0000
# Epoch 00030: val_acc did not improve from 0.56000
# 398/398 [==============================] - 3s 8ms/step - loss: 1.1075e-05 - acc: 1.0000 - val_loss: 2.7119 - val_acc: 0.5300

# %%
model.load_weights("saved_model")
output_x = (test_generator[0][0]/255)
output_y = test_generator[0][1]

# %%
print(model.evaluate(output_x, output_y))
# Out:
# 500/500 [==============================] - 1s 2ms/step
# [0.726129011631012, 0.538]
